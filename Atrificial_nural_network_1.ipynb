# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
from scipy import stats
# Load the dataset (assuming it's in CSV format for this example)
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir("/content/gdrive/MyDrive/Colab Notebooks") # Adjust the path to where the dataset is stored
data = pd.read_csv('Fatality.csv')
# Out:
# Mounted at /content/gdrive

# %%
from sklearn.model_selection import train_test_split
targets = data['comserd']
training_proportion = 0.7
clustering_dataset = data[['mrall','beertax','mlda']]
X_train, X_test, y_train, y_test = train_test_split(clustering_dataset, targets, test_size=1.0 - training_proportion, random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
my_ann_model = MLPClassifier(hidden_layer_sizes=(100,100), max_iter=1000, activation = 'logistic', solver='sgd', learning_rate_init = 0.1, verbose = 1)
my_ann_model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.68465996
# Iteration 2, loss = 0.55244856
# Iteration 3, loss = 0.58442841
# Iteration 4, loss = 0.50191434
# Iteration 5, loss = 0.48878182
# Iteration 6, loss = 0.48851896
# Iteration 7, loss = 0.48931457
# Iteration 8, loss = 0.49450593
# Iteration 9, loss = 0.49557780
# Iteration 10, loss = 0.48897503
# Iteration 11, loss = 0.48913556
# Iteration 12, loss = 0.48890264
# Iteration 13, loss = 0.48893910
# Iteration 14, loss = 0.49324541
# Iteration 15, loss = 0.49263524
# Iteration 16, loss = 0.49739241
# Iteration 17, loss = 0.50220823
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='logistic', hidden_layer_sizes=(100, 100),
#               learning_rate_init=0.1, max_iter=1000, solver='sgd', verbose=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import pylab as pltb
y_predictions = my_ann_model.predict(X_test)
print(classification_report(y_test,y_predictions, zero_division=0))
my_confusion_matrix = confusion_matrix(y_test, y_predictions)
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['comserd'].unique());
ax.yaxis.set_ticklabels(data['comserd'].unique());
# Out:
#               precision    recall  f1-score   support
#
#           no       0.83      1.00      0.91        84
#          yes       0.00      0.00      0.00        17
#
#     accuracy                           0.83       101
#    macro avg       0.42      0.50      0.45       101
# weighted avg       0.69      0.83      0.76       101

# %%
my_ann_model_2 = MLPClassifier(hidden_layer_sizes=(150), max_iter=10, activation = 'logistic', solver='sgd', learning_rate_init = 0.3, verbose = 0)
my_ann_model_2.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='logistic', hidden_layer_sizes=150,
#               learning_rate_init=0.3, max_iter=10, solver='sgd', verbose=0)

# %%
y_predictions_2 = my_ann_model_2.predict(X_test)
print(classification_report(y_test,y_predictions_2, zero_division=0))
my_confusion_matrix = confusion_matrix(y_test, y_predictions_2)
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['comserd'].unique());
ax.yaxis.set_ticklabels(data['comserd'].unique());
# Out:
#               precision    recall  f1-score   support
#
#           no       0.83      1.00      0.91        84
#          yes       0.00      0.00      0.00        17
#
#     accuracy                           0.83       101
#    macro avg       0.42      0.50      0.45       101
# weighted avg       0.69      0.83      0.76       101

# %%
from sklearn.model_selection import train_test_split
targets = data['jaild']
training_proportion = 0.7
clustering_dataset = data[['mrall','beertax','mlda']]
X_train, X_test, y_train, y_test = train_test_split(clustering_dataset, targets, test_size=1.0 - training_proportion, random_state=42)

# %%
from sklearn.neural_network import MLPClassifier
my_ann_model = MLPClassifier(hidden_layer_sizes=(90,90), max_iter=1000, activation = 'logistic', solver='sgd', learning_rate_init = 0.1, verbose = 1)
my_ann_model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.74818114
# Iteration 2, loss = 0.64996097
# Iteration 3, loss = 0.60671918
# Iteration 4, loss = 0.65650494
# Iteration 5, loss = 0.68775838
# Iteration 6, loss = 0.60082422
# Iteration 7, loss = 0.59833461
# Iteration 8, loss = 0.60327341
# Iteration 9, loss = 0.60799860
# Iteration 10, loss = 0.62358414
# Iteration 11, loss = 0.61290478
# Iteration 12, loss = 0.59866488
# Iteration 13, loss = 0.60094714
# Iteration 14, loss = 0.59746573
# Iteration 15, loss = 0.60076389
# Iteration 16, loss = 0.60931276
# Iteration 17, loss = 0.60055708
# Iteration 18, loss = 0.59903160
# Iteration 19, loss = 0.60316670
# Iteration 20, loss = 0.61044072
# Iteration 21, loss = 0.62597285
# Iteration 22, loss = 0.60024952
# Iteration 23, loss = 0.60187601
# Iteration 24, loss = 0.61104210
# Iteration 25, loss = 0.59683788
# Iteration 26, loss = 0.61459007
# Iteration 27, loss = 0.66346881
# Iteration 28, loss = 0.60208099
# Iteration 29, loss = 0.63482026
# Iteration 30, loss = 0.61231540
# Iteration 31, loss = 0.61063409
# Iteration 32, loss = 0.60082436
# Iteration 33, loss = 0.59970172
# Iteration 34, loss = 0.59890806
# Iteration 35, loss = 0.59978034
# Iteration 36, loss = 0.60089029
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(activation='logistic', hidden_layer_sizes=(90, 90),
#               learning_rate_init=0.1, max_iter=1000, solver='sgd', verbose=1)

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import pylab as pltb
y_predictions = my_ann_model.predict(X_test)
print(classification_report(y_test,y_predictions, zero_division=0))
my_confusion_matrix = confusion_matrix(y_test, y_predictions)
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['jaild'].unique());
ax.yaxis.set_ticklabels(data['jaild'].unique());
# Out:
#               precision    recall  f1-score   support
#
#           no       0.73      1.00      0.85        74
#          yes       0.00      0.00      0.00        27
#
#     accuracy                           0.73       101
#    macro avg       0.37      0.50      0.42       101
# weighted avg       0.54      0.73      0.62       101

# %%
my_ann_model_2 = MLPClassifier(hidden_layer_sizes=(20), max_iter=150, activation = 'logistic', solver='sgd', learning_rate_init = 0.1, verbose = 0)
my_ann_model_2.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=20,
#               learning_rate_init=0.1, max_iter=150, solver='sgd', verbose=0)

# %%
y_predictions_2 = my_ann_model_2.predict(X_test)
print(classification_report(y_test,y_predictions_2, zero_division=0))
my_confusion_matrix = confusion_matrix(y_test, y_predictions_2)
fig, ax = pltb.subplots(figsize=(7,4))
sns.heatmap(my_confusion_matrix, annot = True, fmt = 'g', ax = ax);
ax.set_xlabel('Predicted class labels');
ax.set_ylabel('True class labels');
ax.set_title('Confusion matrix');
ax.xaxis.set_ticklabels(data['jaild'].unique());
ax.yaxis.set_ticklabels(data['jaild'].unique());
# Out:
#               precision    recall  f1-score   support
#
#           no       0.73      1.00      0.85        74
#          yes       0.00      0.00      0.00        27
#
#     accuracy                           0.73       101
#    macro avg       0.37      0.50      0.42       101
# weighted avg       0.54      0.73      0.62       101
